# %%
import pandas as pd
import pyspedas
import requests
from pytplot import tplot

# %% [markdown]
# # Sample Data
#
# SITL Report from August 8-9, 2016 (known and cited event from pitch)

# %%
rows = []

report = 'http://www.ssl.berkeley.edu/~moka/eva/list/2016/2016-08-08_170014.txt' #https apparently doesn't work

response = requests.get(report)
data = response.text.splitlines()

keys = ['datetime', 'FOM', 'ID', 'Discussion']

for line in data[15:-1]:
    rows.append(dict(zip(keys, line.split(',', 3))))

df = pd.DataFrame(rows)

# %%
df
# Out:
#                                      datetime    FOM              ID  \
# 0   2016-08-09/03:43:34 - 2016-08-09/03:46:24   20.0   jstawarz(EVA)
# 1   2016-08-09/04:33:04 - 2016-08-09/04:34:24   70.0   jstawarz(EVA)
# 2   2016-08-09/04:34:24 - 2016-08-09/04:35:44   70.0   jstawarz(EVA)
# 3   2016-08-09/04:35:44 - 2016-08-09/04:37:24   70.0   jstawarz(EVA)
# 4   2016-08-09/04:37:24 - 2016-08-09/04:39:04   70.0   jstawarz(EVA)
# ..                                        ...    ...             ...
# 60  2016-08-09/10:07:34 - 2016-08-09/10:09:54   50.0   jstawarz(EVA)
# 61  2016-08-09/10:09:54 - 2016-08-09/10:12:14   50.0   jstawarz(EVA)
# 62  2016-08-09/10:12:14 - 2016-08-09/10:14:44   50.0   jstawarz(EVA)
# 63  2016-08-09/10:14:44 - 2016-08-09/10:17:04   50.0   jstawarz(EVA)
# 64  2016-08-09/10:17:04 - 2016-08-09/10:19:54   50.0   jstawarz(EVA)
#
#                                            Discussion
# 0     Density enhancment with +/-100 km/s flow sig...
# 1     Dipolarization, Flows +/-200 km/s, E and B f...
# 2     Dipolarization, Flows +/-200 km/s, E and B f...
# 3     Dipolarization, Flows +/-200 km/s, E and B f...
# 4     Dipolarization, Flows +/-200 km/s, E and B f...
# ..                                                ...
# 60                          Fill. FPI data available.
# 61                          Fill. FPI data available.
# 62                          Fill. FPI data available.
# 63                          Fill. FPI data available.
# 64                          Fill. FPI data available.
#
# [65 rows x 4 columns]

# %% [markdown]
# Remove rows that do not have "Dipolarization" or "BBF" in them. This can be replaced with ML for language processing as one of the tasks.

# %%
df_DF = df[df.Discussion.str.contains('dipolarization', regex=False, case=False)]
#df = df['bbf' not in df.Discussion.lower()]

# %%
df_BBF = df[df.Discussion.str.contains('bbf', regex=False, case=False)]

# %%
df = df_DF.append(df_BBF) #there could be duplicate rows here

# %%
df
# Out:
#                                      datetime     FOM              ID  \
# 1   2016-08-09/04:33:04 - 2016-08-09/04:34:24    70.0   jstawarz(EVA)
# 2   2016-08-09/04:34:24 - 2016-08-09/04:35:44    70.0   jstawarz(EVA)
# 3   2016-08-09/04:35:44 - 2016-08-09/04:37:24    70.0   jstawarz(EVA)
# 4   2016-08-09/04:37:24 - 2016-08-09/04:39:04    70.0   jstawarz(EVA)
# 5   2016-08-09/07:49:24 - 2016-08-09/07:51:54    49.0   jstawarz(EVA)
# 6   2016-08-09/07:51:54 - 2016-08-09/07:54:24    49.0   jstawarz(EVA)
# 7   2016-08-09/07:54:24 - 2016-08-09/07:56:24    75.0   jstawarz(EVA)
# 8   2016-08-09/07:56:24 - 2016-08-09/07:58:34    75.0   jstawarz(EVA)
# 9   2016-08-09/07:58:34 - 2016-08-09/08:00:34    75.0   jstawarz(EVA)
# 10  2016-08-09/08:00:34 - 2016-08-09/08:02:44    75.0   jstawarz(EVA)
# 17  2016-08-09/08:32:44 - 2016-08-09/08:34:54   110.0   jstawarz(EVA)
# 18  2016-08-09/08:34:54 - 2016-08-09/08:37:04   110.0   jstawarz(EVA)
# 37  2016-08-09/09:19:04 - 2016-08-09/09:20:44   140.0   jstawarz(EVA)
# 38  2016-08-09/09:20:44 - 2016-08-09/09:22:34   140.0   jstawarz(EVA)
# 39  2016-08-09/09:22:34 - 2016-08-09/09:24:14   140.0   jstawarz(EVA)
# 42  2016-08-09/09:28:14 - 2016-08-09/09:29:44   120.0   jstawarz(EVA)
# 43  2016-08-09/09:29:44 - 2016-08-09/09:31:24   120.0   jstawarz(EVA)
# 45  2016-08-09/09:33:34 - 2016-08-09/09:35:24   120.0   jstawarz(EVA)
# 46  2016-08-09/09:35:24 - 2016-08-09/09:37:04   120.0   jstawarz(EVA)
# 47  2016-08-09/09:37:04 - 2016-08-09/09:38:54   120.0   jstawarz(EVA)
# 34  2016-08-09/09:13:34 - 2016-08-09/09:15:34    70.0   jstawarz(EVA)
# 35  2016-08-09/09:15:34 - 2016-08-09/09:17:14    99.0   jstawarz(EVA)
# 36  2016-08-09/09:17:14 - 2016-08-09/09:19:04    99.0   jstawarz(EVA)
# 40  2016-08-09/09:24:14 - 2016-08-09/09:26:14    99.0   jstawarz(EVA)
# 41  2016-08-09/09:26:14 - 2016-08-09/09:28:14    99.0   jstawarz(EVA)
# 44  2016-08-09/09:31:24 - 2016-08-09/09:33:34    99.0   jstawarz(EVA)
#
#                                            Discussion
# 1     Dipolarization, Flows +/-200 km/s, E and B f...
# 2     Dipolarization, Flows +/-200 km/s, E and B f...
# 3     Dipolarization, Flows +/-200 km/s, E and B f...
# 4     Dipolarization, Flows +/-200 km/s, E and B f...
# 5     Some flow perturbations and beginning of dip...
# 6     Some flow perturbations and beginning of dip...
# 7     Dipolarization, E and B field fluctuations, ...
# 8     Dipolarization, E and B field fluctuations, ...
# 9     Dipolarization, E and B field fluctuations, ...
# 10    Dipolarization, E and B field fluctuations, ...
# 17    Dipolarization, increase in temperature, +/-...
# 18    Dipolarization, increase in temperature, +/-...
# 37    Strong flows up to 600 km/s, Dipolarization,...
# 38    Strong flows up to 600 km/s, Dipolarization,...
# 39    Strong flows up to 600 km/s, Dipolarization,...
# 42   Possible dipolarization, Vx -200 km/s, E fiel...
# 43   Possible dipolarization, Vx -200 km/s, E fiel...
# 45    Dipolarization, -200 km/s Vx and 200 km/s Vz...
# 46    Dipolarization, -200 km/s Vx and 200 km/s Vz...
# 47    Dipolarization, -200 km/s Vx and 200 km/s Vz...
# 34                            Gap fill pre-BBF event.
# 35    Pre-BBF event with 300 km/s VX and field act...
# 36    Pre-BBF event with 300 km/s VX and field act...
# 40                  Gap fill within BBF event region.
# 41                  Gap fill within BBF event region.
# 44                  Gap fill within BBF event region.

# %% [markdown]
# Let's now see if we can see this in the observed data. As requested, we want to look at Level 2 products.

# %%
edi_vars = edi(trange=['2016-08-07', '2016-08-10'])
tplot('mms1_edi_vdrift_gse_srvy_l2')
# Out:
# 21-Aug-20 18:34:17: Downloading mms1_edi_srvy_l2_efield_20160807_v0.0.0.cdf to pydata/mms1/edi/srvy/l2/efield/2016/08
# 21-Aug-20 18:34:17: Downloading mms1_edi_srvy_l2_efield_20160808_v0.0.0.cdf to pydata/mms1/edi/srvy/l2/efield/2016/08
# 21-Aug-20 18:34:17: Downloading mms1_edi_srvy_l2_efield_20160809_v0.0.0.cdf to pydata/mms1/edi/srvy/l2/efield/2016/08
# 21-Aug-20 18:34:18: No data loaded.
# mms1_edi_vdrift_gse_srvy_l2 is currently not in pytplot

# %%
tplot

# %%
edi_vars

# %%
fgm_vars = pyspedas.mms.fgm(trange=['2015-10-16', '2015-10-17'])

tplot('mms1_fgm_b_gsm_srvy_l2')
# Out:
# 21-Aug-20 18:40:42: Downloading mms1_fgm_srvy_l2_20151016_v4.18.0.cdf to pydata/mms1/fgm/srvy/l2/2015/10
# The lengths of x and y do not match!
# mms1_fgm_rdeltahalf_srvy_l2 is currently not in pytplot.
# Loaded variables:
# mms1_fgm_b_gse_srvy_l2
# mms1_fgm_b_gsm_srvy_l2
# mms1_fgm_b_dmpa_srvy_l2
# mms1_fgm_b_bcs_srvy_l2
# mms1_fgm_flag_srvy_l2
# mms1_fgm_r_gse_srvy_l2
# mms1_fgm_r_gsm_srvy_l2
# mms1_fgm_hirange_srvy_l2
# mms1_fgm_bdeltahalf_srvy_l2
# mms1_fgm_stemp_srvy_l2
# mms1_fgm_etemp_srvy_l2
# mms1_fgm_mode_srvy_l2
# mms1_fgm_rdeltahalf_srvy_l2
# 21-Aug-20 18:41:46: /Users/smitheb1/Desktop/mms_data_hunt/env/lib/python3.8/site-packages/pytplot/QtPlotter/CustomAxis/AxisItem.py:159: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   color.setAlpha(lineAlpha)
#
# 21-Aug-20 18:41:51: /Users/smitheb1/Desktop/mms_data_hunt/env/lib/python3.8/site-packages/pyqtgraph/widgets/GraphicsView.py:374: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   delta = Point(ev.pos() - QtCore.QPoint(*self.lastMousePos))

# %%
fgm_vars = pyspedas.mms.fgm(trange=['2015-10-16', '2015-10-17'])

tplot('mms1_fgm_b_gsm_srvy_l2')
Search-coil Magnetometer (SCM)
scm_vars = pyspedas.mms.scm(trange=['2015-10-16', '2015-10-17'])

tplot('mms1_scm_acb_gse_scsrvy_srvy_l2')
Electric field Double Probe (EDP)
edp_vars = pyspedas.mms.edp(trange=['2015-10-16', '2015-10-17'])

tplot('mms1_edp_dce_gse_fast_l2')
Electron Drift Instrument (EDI)
edi_vars = pyspedas.mms.edi(trange=['2016-10-16', '2016-10-17'])

tplot('mms1_edi_e_gse_srvy_l2')
Fast Plasma Investigation (FPI)
fpi_vars = pyspedas.mms.fpi(trange=['2015-10-16', '2015-10-17'], datatype='dis-moms')

tplot(['mms1_dis_bulkv_gse_fast', 'mms1_dis_numberdensity_fast'])
Hot Plasma Composition Analyzer (HPCA)
mom_vars = pyspedas.mms.hpca(trange=['2015-10-16', '2015-10-17'], datatype='moments')

tplot(['mms1_hpca_hplus_number_density', 'mms1_hpca_hplus_ion_bulk_velocity'])

# load the ion data
ion_vars = pyspedas.mms.hpca(trange=['2016-10-16', '2016-10-17'], datatype='ion')

from pyspedas import mms_hpca_calc_anodes
from pyspedas import mms_hpca_spin_sum

# average the flux over the full field of view (0-360)
mms_hpca_calc_anodes(fov=[0, 360], probe='1')

# spin-average to calculate the omni-directional flux
mms_hpca_spin_sum()

# show omni-directional flux for H+, O+ and He+, He++
tplot(['mms1_hpca_hplus_flux_elev_0-360_spin', 
             'mms1_hpca_oplus_flux_elev_0-360_spin', 
             'mms1_hpca_heplus_flux_elev_0-360_spin', 
             'mms1_hpca_heplusplus_flux_elev_0-360_spin'])
Energetic Ion Spectrometer (EIS)
from pyspedas import mms_eis_pad

eis_vars = pyspedas.mms.eis(trange=['2015-10-16', '2015-10-17'], datatype=['phxtof', 'extof'])

# plot the non-spin averaged flux
tplot(['mms1_epd_eis_extof_proton_flux_omni', 'mms1_epd_eis_phxtof_proton_flux_omni'])

# plot the spin averaged flux
tplot(['mms1_epd_eis_extof_proton_flux_omni_spin', 'mms1_epd_eis_phxtof_proton_flux_omni_spin'])

# calculate the ExTOF pitch angle distribution
mms_eis_pad(datatype='extof')

tplot(['mms1_epd_eis_extof_56-535keV_proton_flux_omni_pad_spin', 'mms1_epd_eis_extof_56-535keV_proton_flux_omni_pad'])
Fly's Eye Energetic Particle Sensor (FEEPS)
from pyspedas import mms_feeps_pad

feeps_data = pyspedas.mms.feeps(trange=['2015-10-16', '2015-10-17'], datatype='electron')

tplot(['mms1_epd_feeps_srvy_l2_electron_intensity_omni_spin', 'mms1_epd_feeps_srvy_l2_electron_intensity_omni'])

# calculate the electron pitch angle distribution
mms_feeps_pad(datatype='electron')

tplot(['mms1_epd_feeps_srvy_l2_electron_intensity_70-600keV_pad_spin', 'mms1_epd_feeps_srvy_l2_electron_intensity_70-600keV_pad'])
Active Spacecraft Potential Control (ASPOC)
asp_data = pyspedas.mms.aspoc(trange=['2015-10-16', '2015-10-17'])

tplot('mms1_aspoc_ionc')
MMS Ephemeris and Coordinates (MEC)
mec_data = pyspedas.mms.mec(trange=['2015-10-16', '2015-10-17'])

tplot(['mms1_mec_r_gsm', 'mms1_mec_v_gsm'])
Digital Signal Processor (DSP)
dsp_data = pyspedas.mms.dsp(trange=['2015-10-16', '2015-10-17'], data_rate='fast', datatype='bpsd')

tplot('mms1_dsp_bpsd_omni_fast_l2')
